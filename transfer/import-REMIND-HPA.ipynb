# %%
import ixmp4
import pyam

# %%
df = pyam.IamDataFrame("raw/REMIND-HPA.xlsx")

# %%
df.set_meta(meta="Rescuing 1.5°C [IKEA Foundation]", name="Project")
df.set_meta(meta="n/a", name="Scientific Manuscript (DOI)")
df.set_meta(meta="Climate Analytics & PIK (2025)", name="Scientific Manuscript (Citation)")

# %%
df.rename(
    scenario={"HighestPossibleAmbition": "Rescuing-1.5°C-Highest-Possible-Ambition"},
    inplace=True,
)

# %%
platform = ixmp4.Platform("scenariocompass-transfer")

# %%
df.to_ixmp4(platform)
