# %%
import ixmp4
import pyam
from pathlib import Path

# %%
platform = ixmp4.Platform("scenariocompass-sandbox")

# %%
platform.runs.tabulate()

# %%
df = pyam.read_ixmp4(
    platform,
    model="REMIND 3.5",
    scenario="HighestPossibleAmbition",
)

# %%
df.to_excel("raw/REMIND-HPA.xlsx")
